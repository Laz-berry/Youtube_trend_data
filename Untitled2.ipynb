# %%
import re
import pandas as pd

# %%
# Prepare data
df3 = pd.read_csv('Trend_data.csv')

# %%
df3
# Out:
#            video_id                                              title
# 0       uq5LClQN3cE                                        안녕하세요 보겸입니다  \
# 1       I-ZbZCHsHD0                                 부락토스의 계획 [총몇명 프리퀄]
# 2       9d7jNUjBoss                                    평생 반성하면서 살겠습니다.
# 3       3pI_L3-sMVg                               안녕하세요 꽈뚜룹입니다.
# 4       zrsBjYukE8s   박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
# ...             ...                                                ...
# 184860  PIBsD-TL-a8    24시간동안 통으로 먹기 VS 조각 내서 먹기!! 통째로 먹는 게 무조건 맛있을까?!
# 184861  SK282KBKadk  [GOING SEVENTEEN] EP.66 기습 돈't Lie #1 (Surpris...
# 184862  dcd-xWPh8xs                7개월만에 다시 가 본 , 오사카 야끼니꾸!! 어떻게 변했을까?
# 184863  3iB6RQAC7Bk  [4K] STAYC(스테이씨) - “Teddy Bear” Band LIVE Conc...
# 184864  f7I-82uWuyM      혼자 인도를 여행하는 일본 여자를 구해주다 / 인도, 타지마할 - 인도(3) 🇮🇳
#
#                 published_at       channel_title  categoryId
# ...

# %%
df4 = df3[df3['categoryId'] == 24]
df2 = df3[df3['categoryId'] == 22]

# %%
df4 = df4[['trending_date', 'tags']]
df2 = df2[['trending_date', 'tags']]
df4['trending_date'] = pd.to_datetime(df4['trending_date'])
df2['trending_date'] = pd.to_datetime(df2['trending_date'])

# %%
df4.to_csv('1.csv', index=False)
df2.to_csv('2.csv', index=False)
